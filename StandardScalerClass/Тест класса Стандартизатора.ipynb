# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from stepanlearn import StepanStandartizator

# %%
X = np.random.uniform(low=100, high=130, size=1000000)

# %%
print(X.min(), X.max(), X.mean(), np.median(X))
# Out:
# 100.00000270249498 129.9999264017361 114.99244677389689 114.9931391630724

# %%
X_numpy = X.reshape([10000,100])

# %%
X_pandas = pd.DataFrame(X_numpy)

# %%
X_pandas
# Out:
#               0           1           2           3           4           5   \
# 0     113.526345  121.465108  110.965030  114.639110  100.481032  110.228079
# 1     123.168516  127.161825  112.805279  106.772117  108.372170  118.725044
# 2     111.291801  116.114065  101.695267  117.452732  116.787492  100.662431
# 3     120.865515  109.029931  117.493559  111.863378  129.078516  128.541997
# 4     105.125269  115.104379  100.142970  109.766842  105.847440  124.590579
# ...          ...         ...         ...         ...         ...         ...
# 9995  117.523881  117.500870  115.970261  116.421520  110.504188  113.831869
# 9996  112.932399  105.140813  116.793385  102.190138  101.110224  127.890427
# 9997  122.252484  110.432808  118.331345  102.215585  120.091425  109.134458
# 9998  104.630131  124.195433  116.890130  103.108276  125.390281  118.129256
# 9999  113.302049  110.598884  108.029451  108.525120  124.759029  121.233944
#
#               6           7           8           9   ...          90  \
# 0     106.802689  104.483364  102.973327  102.481105  ...  114.916682
# 1     128.949234  115.495159  123.646675  110.146609  ...  111.446235
# 2     128.437393  122.102427  122.265752  101.482737  ...  121.372516
# 3     113.259214  105.238344  128.552915  121.883280  ...  111.257740
# 4     113.250113  120.749548  114.285541  103.117664  ...  116.050840
# ...          ...         ...         ...         ...  ...         ...
# 9995  105.415201  122.028365  103.757066  117.912894  ...  101.077420
# 9996  127.153801  114.757877  113.702204  101.317977  ...  110.751723
# 9997  100.458029  122.203953  105.929930  111.560941  ...  116.815297
# 9998  111.506170  103.617398  109.969922  110.023547  ...  107.282042
# 9999  122.649107  108.147954  127.356645  121.491299  ...  121.014770
#
#               91          92          93          94          95          96  \
# 0     100.020089  106.814317  123.477242  123.263025  106.757217  106.311647
# 1     123.871197  101.336404  123.871046  100.670889  102.461863  123.288813
# 2     114.865842  107.346666  103.714329  109.437661  107.210709  111.691962
# 3     100.526789  113.186227  117.282020  116.460592  122.386657  110.000576
# 4     100.143083  104.644513  128.046855  113.718215  110.606854  116.442535
# ...          ...         ...         ...         ...         ...         ...
# 9995  120.434814  113.684447  108.454337  126.965715  100.526081  116.654743
# 9996  105.163930  116.563986  105.892642  127.322697  122.358292  126.641735
# 9997  119.506137  105.748113  124.251345  128.487695  113.768678  114.137362
# 9998  107.838390  106.789665  113.613899  117.508896  116.765518  124.985117
# 9999  103.276379  102.938001  105.880807  123.792998  112.421079  103.311555
#
#               97          98          99
# 0     124.980055  104.219589  101.573276
# 1     124.690963  118.887079  124.220925
# 2     106.013473  120.966869  117.419824
# 3     117.997481  106.350370  128.889648
# 4     106.914121  127.320512  114.144737
# ...          ...         ...         ...
# 9995  103.234468  115.523645  103.484075
# 9996  122.119005  127.734161  105.987674
# 9997  117.061644  125.119414  123.587838
# 9998  125.556755  104.661423  111.076518
# 9999  109.850510  107.165376  116.817481
#
# [10000 rows x 100 columns]

# %%
X_numpy
# Out:
# array([[113.5263448 , 121.46510782, 110.96503026, ..., 124.98005523,
#         104.219589  , 101.57327588],
#        [123.1685156 , 127.16182479, 112.80527941, ..., 124.69096339,
#         118.88707852, 124.22092503],
#        [111.29180135, 116.11406477, 101.69526692, ..., 106.01347306,
#         120.96686852, 117.41982353],
#        ...,
#        [122.25248419, 110.43280814, 118.3313453 , ..., 117.06164404,
#         125.11941405, 123.58783812],
#        [104.63013073, 124.19543341, 116.8901295 , ..., 125.55675536,
#         104.66142256, 111.07651786],
#        [113.30204874, 110.59888441, 108.02945124, ..., 109.85050952,
#         107.16537609, 116.81748126]])

# %%
sklearn_scaler = StandardScaler()
stepan_scaler = StepanStandartizator()

# %%
# %timeit sklearn_scaler.fit(X_numpy)
# Out:
# 17 ms ± 442 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit stepan_scaler.fit(X_numpy)
# Out:
# 13.5 ms ± 203 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit sklearn_scaler.transform(X_numpy)
# Out:
# 6.7 ms ± 109 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit stepan_scaler.transform(X_numpy)
# Out:
# 1.85 s ± 38.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
