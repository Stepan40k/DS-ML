# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from stepanlearn import StepanStandartizator

# %%
X = np.random.uniform(low=100, high=130, size=1000000)

# %%
print(X.min(), X.max(), X.mean(), np.median(X))
# Out:
# 100.00002238746704 129.99999051748654 115.00983460143992 115.01930361949549

# %%
X_numpy = X.reshape([10000,100])

# %%
X_pandas = pd.DataFrame(X_numpy)

# %%
X_pandas
# Out:
#               0           1           2           3           4           5   \
# 0     122.286559  111.707664  108.108338  116.598557  120.471306  109.769935
# 1     119.484867  123.360423  115.986143  118.581032  126.036553  128.928410
# 2     129.907187  112.761186  115.473707  109.227018  111.413587  127.437048
# 3     108.651082  121.664227  102.417995  128.409623  122.713714  102.891840
# 4     115.508383  109.981293  104.438627  129.837931  106.860529  102.733616
# ...          ...         ...         ...         ...         ...         ...
# 9995  102.050896  108.419487  109.361394  104.618515  108.646415  125.283351
# 9996  115.620644  101.492785  128.783860  128.391646  110.401559  109.722501
# 9997  114.320835  111.439466  117.906266  125.776302  117.193670  121.446400
# 9998  119.254815  109.801683  101.666439  127.363820  121.645334  128.784414
# 9999  123.536723  100.073223  101.052030  117.382972  115.975129  125.622525
#
# ...

# %%
X_numpy
# Out:
# array([[122.28655929, 111.70766423, 108.10833797, ..., 117.39889086,
#         117.85799218, 129.46320329],
#        [119.48486704, 123.36042303, 115.98614272, ..., 101.10172149,
#         113.72576633, 102.71405198],
#        [129.9071866 , 112.76118563, 115.47370721, ..., 108.95914294,
#         127.27043934, 118.17746774],
#        ...,
#        [114.32083458, 111.4394658 , 117.90626602, ..., 102.26468277,
#         112.63025155, 125.91371922],
#        [119.25481502, 109.80168346, 101.66643856, ..., 124.80855941,
#         119.72568322, 125.06669071],
#        [123.53672272, 100.07322285, 101.05202969, ..., 119.38141734,
#         122.48360155, 112.81988977]])

# %%
sklearn_scaler = StandardScaler()
stepan_scaler = StepanStandartizator()

# %%
# %timeit sklearn_scaler.fit(X_pandas)
# Out:
# 18.3 ms ± 182 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit stepan_scaler.fit(X_pandas)
# Out:
# 57.4 ms ± 1.39 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit sklearn_scaler.transform(X_pandas)
# Out:
# 7.41 ms ± 242 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit stepan_scaler.transform(X_pandas)
# Out:
# 49.9 ms ± 793 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
